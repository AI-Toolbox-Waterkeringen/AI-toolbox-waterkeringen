# %%
import os

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import PolyCollection
import geopandas as gpd
import pandas as pd
import PIL
from pathlib import Path
import tqdm
import rasterio.features
import shapely.geometry
import utils

# COCO tools
import pycocotools.mask
from pycocotools.coco import COCO

# # Recognize Anything Model & Tag2Text
# from ram.models import ram_plus
# from ram import inference_ram
# import torchvision.transforms as TS

# Grounding Dino
from groundingdino.util.inference import load_model
import groundingdino.datasets.transforms as T
from groundingdino.util.utils import get_phrases_from_posmap
import glob

# Segment anything
from segment_anything_hq import (
    SamPredictor as SamPredictor_hq,
    sam_model_registry as sam_model_registry_hq,
)
from segment_anything import SamPredictor, sam_model_registry
# Out:
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/segment_anything_hq/modeling/tiny_vit_sam.py:662: UserWarning: Overwriting tiny_vit_5m_224 in registry with segment_anything_hq.modeling.tiny_vit_sam.tiny_vit_5m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/segment_anything_hq/modeling/tiny_vit_sam.py:662: UserWarning: Overwriting tiny_vit_11m_224 in registry with segment_anything_hq.modeling.tiny_vit_sam.tiny_vit_11m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/segment_anything_hq/modeling/tiny_vit_sam.py:662: UserWarning: Overwriting tiny_vit_21m_224 in registry with segment_anything_hq.modeling.tiny_vit_sam.tiny_vit_21m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/segment_anything_hq/modeling/tiny_vit_sam.py:662: UserWarning: Overwriting tiny_vit_21m_384 in registry with segment_anything_hq.modeling.tiny_vit_sam.tiny_vit_21m_384. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/segment_anything_hq/modeling/tiny_vit_sam.py:662: UserWarning: Overwriting tiny_vit_21m_512 in registry with segment_anything_hq.modeling.tiny_vit_sam.tiny_vit_21m_512. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)

# %%
# def load_image(image_path):
#     # load image
#     image_pil = PIL.Image.open(image_path).convert("RGB")  # load image

#     transform = T.Compose(
#         [
#             T.RandomResize([800], max_size=1333),
#             T.ToTensor(),
#             T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
#         ]
#     )
#     image, _ = transform(image_pil, None)  # 3, h, w
#     return image_pil, image

# def get_grounding_output(model, image, caption, box_threshold, text_threshold,device="cpu"):
#     """

#     """
#     caption = caption.lower()
#     caption = caption.strip()
#     if not caption.endswith("."):
#         caption = caption + "."
#     model = model.to(device)
#     image = image.to(device)
#     with torch.no_grad():
#         outputs = model(image[None], captions=[caption])
#     logits = outputs["pred_logits"].cpu().sigmoid()[0]  # (nq, 256)
#     boxes = outputs["pred_boxes"].cpu()[0]  # (nq, 4)
#     logits.shape[0]

#     # filter output
#     logits_filt = logits.clone()
#     boxes_filt = boxes.clone()
#     filt_mask = logits_filt.max(dim=1)[0] > box_threshold
#     logits_filt = logits_filt[filt_mask]  # num_filt, 256
#     boxes_filt = boxes_filt[filt_mask]  # num_filt, 4
#     logits_filt.shape[0]

#     # get phrase
#     tokenlizer = model.tokenizer
#     tokenized = tokenlizer(caption)
#     # build pred
#     pred_phrases = []
#     scores = []
#     for logit, box in zip(logits_filt, boxes_filt):
#         pred_phrase = get_phrases_from_posmap(logit > text_threshold, tokenized, tokenlizer)
#         pred_phrases.append(pred_phrase + f"({str(logit.max().item())[:4]})")
#         scores.append(logit.max().item())
#     return boxes_filt, torch.Tensor(scores), pred_phrases


# def show_mask(mask, ax, random_color=False):
#     if random_color:
#         color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
#     else:
#         color = np.array([30/255, 144/255, 255/255, 0.6])
#     h, w = mask.shape[-2:]
#     mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
#     ax.imshow(mask_image)


# def show_box(box, ax, label):
#     x0, y0 = box[0], box[1]
#     w, h = box[2] - box[0], box[3] - box[1]
#     ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))
#     ax.text(x0, y0, label)


# def save_mask_data(output_dir, tags_chinese, mask_list, box_list, label_list):
#     value = 0  # 0 for background

#     mask_img = torch.zeros(mask_list.shape[-2:])
#     for idx, mask in enumerate(mask_list):
#         mask_img[mask.cpu().numpy()[0] == True] = value + idx + 1
#     plt.figure(figsize=(10, 10))
#     plt.imshow(mask_img.numpy())
#     plt.axis('off')
#     plt.savefig(os.path.join(output_dir, 'mask.jpg'), bbox_inches="tight", dpi=300, pad_inches=0.0)

#     json_data = {
#         'tags_chinese': tags_chinese,
#         'mask':[{
#             'value': value,
#             'label': 'background'
#         }]
#     }
#     for label, box in zip(label_list, box_list):
#         value += 1
#         name, logit = label.split('(')
#         logit = logit[:-1] # the last is ')'
#         json_data['mask'].append({
#             'value': value,
#             'label': name,
#             'logit': float(logit),
#             'box': box.numpy().tolist(),
#         })
#     with open(os.path.join(output_dir, 'label.json'), 'w') as f:
#         json.dump(json_data, f)

# %%
# # Dino thresholds
# DINO_BOX_THRESHOLD = 0.2
# DINO_TEXT_THRESHOLD = 0.2

# # Boxes merge
# DO_IOU_MERGE = True
# IOU_THRESHOLD = 0.5

# # tiffbounds
# path_tifftiles = Path("data/tile_dataset")

# DEVICE = "cuda:1"

# fixed_tags = True
# RAM_CHECKPOINT = ".//ram_weights/ram_plus_swin_large_14m.pth"
# RAM_MODELTYPE = "swin_l"

# GROUNDING_DINO_CONFIG_PATH = "config/GroundingDINO_SwinB_cfg.py"
# GROUNDING_DINO_CHECKPOINT_PATH = "data/dino_weights/groundingdino_swinb_cogcoor.pth"


# USE_SAM_HQ = False
# SAM_ENCODER_VERSION = "vit_h"
# SAM_CHECKPOINT_PATH = "data/sam_weights/sam_vit_h_4b8939.pth"
# SAM_HQ_ENCODER_VERSION = "vit_h"
# SAM_HQ_CHECKPOINT_PATH = "data/sam_weights/sam_hq_vit_h.pth"

# %%
# initialize Recognize Anything Model (RAM)
# normalize = TS.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# transform = TS.Compose([TS.Resize((384, 384)), TS.ToTensor(), normalize])
# ram_model = ram_plus(pretrained=RAM_CHECKPOINT, image_size=384, vit=RAM_MODELTYPE)
# pd.DataFrame(dict(ram_class=ram_model.tag_list, ram_threshold=ram_model.class_threshold)).to_csv("RAM_tag_list.csv")
# # ram_model.class_threshold = torch.ones(ram_model.num_class) * RAM_THRESHOLD

# ram_model.eval()
# ram_model = ram_model.to(DEVICE)


from hydra import initialize, compose

with initialize("config", version_base=None):
    cfg = compose("config.yaml")

print(cfg)
# Load grounding dino model
dino_model = load_model(
    cfg.GROUNDING_DINO_CONFIG_PATH,
    cfg.GROUNDING_DINO_CHECKPOINT_PATH,
    device=cfg.DEVICE,
)

# Segment Anything Model (SAM)

if cfg.USE_SAM_HQ:
    print("Initialize SAM-HQ Predictor")
    sam = sam_model_registry_hq[cfg.SAM_HQ_ENCODER_VERSION](
        checkpoint=cfg.SAM_HQ_CHECKPOINT_PATH
    ).to(device=cfg.DEVICE)
    sam_predictor = SamPredictor_hq(sam)
else:
    sam = sam_model_registry[cfg.SAM_ENCODER_VERSION](
        checkpoint=cfg.SAM_CHECKPOINT_PATH
    ).to(device="cuda:1")
    sam_predictor = SamPredictor(sam)
# Out:
# {'device': 'cuda:1', 'hq': False, 'model_type': 'vit_b', 'disk_path': './', 'data_path': '${disk_path}/data', 'checkpoint': 'sam_vit_b_01ec64.pth', 'DEVICE': 'cuda:1', 'DINO_BOX_THRESHOLD': 0.2, 'DINO_TEXT_THRESHOLD': 0.0, 'DO_IOU_MERGE': True, 'IOU_THRESHOLD': 0.5, 'dataDir': '${data_path}/supervisely/277426_20230714 MUG Hoorn Enkhuizen orthomosaic deel 6/2023-12-11 12_52_14.810', 'path_tifftiles': '${data_path}/label_data', 'use_fixed_tags': True, 'RAM_CHECKPOINT': '${disk_path}/ram_weights/ram_plus_swin_large_14m.pth', 'RAM_MODELTYPE': 'swin_l', 'GROUNDING_DINO_CONFIG_PATH': 'config/GroundingDINO_SwinB_cfg.py', 'GROUNDING_DINO_CHECKPOINT_PATH': '${disk_path}/dino_weights/groundingdino_swinb_cogcoor.pth', 'USE_SAM_HQ': False, 'SAM_ENCODER_VERSION': 'vit_h', 'SAM_CHECKPOINT_PATH': '${disk_path}/sam_weights/sam_vit_h_4b8939.pth', 'SAM_HQ_ENCODER_VERSION': 'vit_h', 'SAM_HQ_CHECKPOINT_PATH': '${disk_path}/sam_weights/sam_hq_vit_h.pth', 'fixed_tags': ['bush', 'grass', 'road', 'shrub', 'stone', 'tree', 'water'], 'dike_traject_fnames': ['Zetsteen shapefile traject 12-2.shp', 'Zetsteen shapefile traject 13-7.shp'], 'dike_traject_havenhoofden_fnames': ['Zetsteen shapefile havendammen.shp'], 'tile_overlap_threshold': 0.1, 'tile_size_x': 2048, 'tile_size_y': 2048}
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025842427/work/aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# final text_encoder_type: bert-base-uncased

# %%
def find_tile_bounds(root_tilepath, concat=True):
    """
    Recursively search through directories starting from root_tilepath to find and optionally concatenate
    geospatial data files (.gpkg) that include 'cells_intersect' in their filename.

    Parameters:
    - root_tilepath (str or pathlib.Path): The root directory path where the search for tile files begins.
    - concat (bool, optional): If True, concatenates all found geospatial data into a single DataFrame.
                               If False, returns a list of DataFrames. Default is True.

    Returns:
    - pandas.DataFrame or list of geopandas.GeoDataFrame: The concatenated DataFrame of all files if `concat=True`,
      or a list of DataFrames for each file if `concat=False`.

    """
    cell_files = []
    for p in Path(str(root_tilepath)).iterdir():
        if p.is_dir():
            cell_files += find_tile_bounds(p, concat=False)
        elif p.is_file() and p.suffix == ".gpkg" and "tiles_intersect" in p.stem:
            df = gpd.read_file(p)
            df["name"] = p.stem.replace("_tiles_intersects", "")
            cell_files.append(df.copy())

    if concat:
        cell_files = pd.concat(cell_files)

    return cell_files


# tilebounds
df_tilebounds = find_tile_bounds(Path(cfg.disk_path) / "tile_dataset")

# %%
df_tilebounds
# Out:
#       value           xmin           ymin           xmax           ymax  \
# 0     955.0  132639.000265  516747.338667  132653.294654  516761.963073
# 1    1099.0  132653.294654  516747.338667  132667.589042  516761.963073
# 2    1303.0  132653.294654  516732.714261  132667.589042  516747.338667
# 3     485.0  132653.294654  516718.089855  132667.589042  516732.714261
# 4    1698.0  132653.294654  516703.465449  132667.589042  516718.089855
# ..      ...            ...            ...            ...            ...
# 257  3652.0  135800.650750  541446.857428  135815.002085  541461.469639
# 258  3510.0  135815.002085  541446.857428  135829.353419  541461.469639
# 259  6487.0  135815.002085  541432.245217  135829.353419  541446.857428
# 260  8928.0  135815.002085  541417.633006  135829.353419  541432.245217
# 261  2214.0  135829.353419  541417.633006  135843.704753  541432.245217
#
#                                               geometry  \
# 0    POLYGON ((132639.000 516761.963, 132639.000 51...
# 1    POLYGON ((132653.295 516761.963, 132653.295 51...
# 2    POLYGON ((132653.295 516747.339, 132653.295 51...
# 3    POLYGON ((132653.295 516732.714, 132653.295 51...
# 4    POLYGON ((132653.295 516718.090, 132653.295 51...
# ..                                                 ...
# 257  POLYGON ((135800.651 541461.470, 135800.651 54...
# 258  POLYGON ((135815.002 541461.470, 135815.002 54...
# 259  POLYGON ((135815.002 541446.857, 135815.002 54...
# 260  POLYGON ((135815.002 541432.245, 135815.002 54...
# 261  POLYGON ((135829.353 541432.245, 135829.353 54...
#
#                                                   name
# 0      20230714 MUG Hoorn Enkhuizen orthomosaic deel 1
# 1      20230714 MUG Hoorn Enkhuizen orthomosaic deel 1
# 2      20230714 MUG Hoorn Enkhuizen orthomosaic deel 1
# 3      20230714 MUG Hoorn Enkhuizen orthomosaic deel 1
# 4      20230714 MUG Hoorn Enkhuizen orthomosaic deel 1
# ..                                                 ...
# 257  20230714 MUG Medemblik Den Oever orthomosaic d...
# 258  20230714 MUG Medemblik Den Oever orthomosaic d...
# 259  20230714 MUG Medemblik Den Oever orthomosaic d...
# 260  20230714 MUG Medemblik Den Oever orthomosaic d...
# 261  20230714 MUG Medemblik Den Oever orthomosaic d...
#
# [3854 rows x 7 columns]

# %%
out_dir = Path(cfg.disk_path) / "output"
if not out_dir.exists():
    out_dir.mkdir()
else:
    print(f"Directory {out_dir} already exists!")
# Out:
# Directory .//output already exists!

# %%
supervisely_path = Path(cfg.disk_path) / "supervisely" / "2023*"
dataDirs = [Path(p) for p in glob.glob(str(supervisely_path))]

for dataDir in dataDirs:

    # initialize COCO api for instance annotations
    coco = COCO(dataDir.joinpath("annotations/instances.json"))
    cats = coco.loadCats(coco.getCatIds())
    nms = [cat["name"] for cat in cats]
    catIds = coco.getCatIds(catNms=nms)
    imgIds = coco.getImgIds()

    # fig = plt.figure(figsize=(20, 10), dpi=100)

    df_pred_shapes = dict(
        category=[],
        confidence=[],
        tile_path=[],
        project_name=[],
        tile_fname=[],
        geometry=[],
    )
    df_seg_shapes = dict(
        category=[], tile_path=[], tile_fname=[], project_name=[], geometry=[]
    )

    projName = (
        Path(glob.glob(f"{str(dataDir)}/images/*")[0])
        .stem.split("_")[0]
        .replace(" ", "_")
    )

    for imgId in tqdm.tqdm(imgIds):
        # COCO format image path and annotation
        img = coco.loadImgs(imgId)[0]
        imgPath = dataDir.joinpath("images").joinpath(img["file_name"])
        anns = {}
        for catId in catIds:
            anns[catId] = coco.loadAnns(
                coco.getAnnIds(imgIds=img["id"], catIds=[catId], iscrowd=None)
            )

        # Load image
        image_pil, image = utils.load_image(imgPath)

        # Tags
        if cfg.fixed_tags:
            tags = ",".join(cfg.fixed_tags)
        else:
            # Find tags with RAM
            ram_model = ram_model.to(cfg.DEVICE)
            raw_image = image_pil.resize((384, 384))
            raw_image = transform(raw_image).unsqueeze(0).to(cfg.DEVICE)
            res = inference_ram(raw_image, ram_model)
            tags = res[0].replace(" |", ",")

        # Find bounding boxes with grounding dino
        boxes_filt, scores, pred_phrases = utils.get_grounding_output(
            dino_model,
            image,
            tags,
            cfg.DINO_BOX_THRESHOLD,
            cfg.DINO_TEXT_THRESHOLD,
            device=cfg.DEVICE,
        )

        # Resize boxes
        size = image_pil.size
        H, W = size[1], size[0]
        for i in range(boxes_filt.size(0)):
            boxes_filt[i] = boxes_filt[i] * torch.Tensor([W, H, W, H]).to(cfg.device)
            boxes_filt[i][:2] -= boxes_filt[i][2:] / 2
            boxes_filt[i][2:] += boxes_filt[i][:2]

        # use NMS to handle overlapped boxes
        boxes_filt = boxes_filt.cpu()
        nms_idx = (
            torchvision.ops.nms(boxes_filt, scores, cfg.IOU_THRESHOLD).numpy().tolist()
        )
        if cfg.DO_IOU_MERGE:
            boxes_filt_clean = boxes_filt[nms_idx]
            pred_phrases_clean = [pred_phrases[idx] for idx in nms_idx]
            # print(f"NMS: before {boxes_filt.shape[0]} boxes, after {boxes_filt_clean.shape[0]} boxes")
        else:
            boxes_filt_clean = boxes_filt
            pred_phrases_clean = pred_phrases

        # Segment objects with SAM
        image_np = np.array(image_pil)
        sam_predictor.set_image(image_np)
        transformed_boxes = sam_predictor.transform.apply_boxes_torch(
            boxes_filt_clean, image_np.shape[:2]
        ).to(cfg.DEVICE)
        masks, _, _ = sam_predictor.predict_torch(
            point_coords=None,
            point_labels=None,
            boxes=transformed_boxes.to(cfg.DEVICE),
            multimask_output=False,
        )

        # Find tile bounds (X, Y) based on name
        imgName = ".".join(coco.imgs[imgId]["file_name"].split(".")[:-1])
        tile1a = imgName.split("_")[0]
        tile1b = int(imgName.split("_")[-1])
        cellfile = df_tilebounds[
            (df_tilebounds.index == tile1b) & (df_tilebounds.name == tile1a)
        ].copy()
        assert len(cellfile) == 1
        cellfile = cellfile.iloc[0, :].copy()
        xstep = (cellfile.xmax - cellfile.xmin) / image_np.shape[1]
        ystep = (cellfile.ymax - cellfile.ymin) / image_np.shape[0]

        affine = [xstep, 0, cellfile.xmin, 0, -ystep, cellfile.ymax, 0, 0, 1]

        # SAM masks
        assert len(pred_phrases_clean) == len(masks)
        shapes, titles = [], []
        for cat_title, mask in zip(pred_phrases_clean, masks):
            mask = mask.cpu().numpy()
            cat_shapes = rasterio.features.shapes(
                mask.astype(np.uint8), mask=mask, connectivity=4, transform=affine
            )
            for shape, _ in cat_shapes:
                title, confidence = cat_title.replace(")", "").split("(")
                shape = shapely.geometry.shape(shape).simplify(
                    0.01, preserve_topology=True
                )
                if shape.area > 0.01:
                    df_pred_shapes["category"].append(title)
                    df_pred_shapes["confidence"].append(confidence)
                    df_pred_shapes["geometry"].append(shape)
                    df_pred_shapes["tile_path"].append(str(imgPath))
                    df_pred_shapes["tile_fname"].append(imgPath.stem)
                    df_pred_shapes["project_name"].append(projName)

        # COCO masks
        for catId, catName in zip(catIds, nms):

            for ann in anns[catId]:
                t = coco.imgs[ann["image_id"]]

                if type(ann["segmentation"]["counts"]) == list:
                    rle = pycocotools.mask.frPyObjects(
                        [ann["segmentation"]], t["height"], t["width"]
                    )
                else:
                    rle = [ann["segmentation"]]

                m = pycocotools.mask.decode(rle)[:, :, 0]
                cat_shapes = rasterio.features.shapes(
                    m.astype(np.uint8), mask=m, connectivity=4, transform=affine
                )

                for shape, _ in cat_shapes:
                    title, confidence = cat_title.replace(")", "").split("(")
                    shape = shapely.geometry.shape(shape).simplify(
                        0.01, preserve_topology=True
                    )
                    if shape.area > 0.01:
                        df_seg_shapes["category"].append(catName)
                        df_seg_shapes["geometry"].append(shape)

                        df_seg_shapes["tile_path"].append(str(imgPath))
                        df_seg_shapes["tile_fname"].append(imgPath.stem)
                        df_seg_shapes["project_name"].append(projName)

        # # Clear figure and add axis
        # fig.clear()
        # axs = fig.subplots(1, 2, squeeze=False)

        # # Draw supervisely image (COCO format)
        # axs[0,0].imshow(image_np)
        # i_end = 0
        # legend_handles = []
        # for catId, catName in zip(catIds, nms):
        #     plt.sca(axs[0,0])
        #     coco.showAnns(anns[catId], draw_bbox=True)
        #     for ann in anns[catId]:
        #         plt.text(ann["bbox"][0], ann["bbox"][1] - 5, catName, fontsize=10)

        # # draw RAM-Dino-SAM image
        # axs[0,1].imshow(image_np)
        # for mask in masks:
        #     show_mask(mask.cpu().numpy(), axs[0,1], random_color=True)

        # for box, label in zip(boxes_filt_clean, pred_phrases_clean):
        #     show_box(box.numpy(), axs[0,1], label)

        # # Set titles
        # axs[0,0].set_title("Supervisely")
        # axs[0,1].set_title(f"RAM-DINO-SAM, tags: {tags}", wrap=True)

        # # Dont show axis
        # axs[0,0].axis("off")
        # axs[0,1].axis("off")

        # # Save figure
        # if fixed_tags:
        #     if USE_SAM_HQ:
        #         plt_dir = pathlib.Path("test_output/fixed_tags_hq")
        #     else:
        #         plt_dir = pathlib.Path("test_output/fixed_tags")
        # else:
        #     if USE_SAM_HQ:
        #         plt_dir = pathlib.Path("test_output/ram_tags_hq")
        #     else:
        #         plt_dir = pathlib.Path("test_output/ram_tags")
        # plt_dir.mkdir(parents=True, exist_ok=True)
        # fig.savefig(plt_dir.joinpath(imgPath.name), bbox_inches="tight")

    df_pred_shapes = gpd.GeoDataFrame(df_pred_shapes, crs="epsg:28992")
    if cfg.USE_SAM_HQ:
        df_pred_shapes.to_file(out_dir / f"/fix_tags_hq_{projName}.gpkg")
    else:
        df_pred_shapes.to_file(out_dir / f"fix_tags_{projName}.gpkg")

    df_seg_shapes = gpd.GeoDataFrame(df_seg_shapes, crs="epsg:28992")
    df_seg_shapes.to_file(out_dir / f"supervisely_tags_{projName}.gpkg")
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#   1%|▏         | 1/78 [00:00<01:05,  1.17it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#   3%|▎         | 2/78 [00:01<01:00,  1.25it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#   4%|▍         | 3/78 [00:02<00:58,  1.28it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#   5%|▌         | 4/78 [00:03<00:57,  1.30it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#   6%|▋         | 5/78 [00:03<00:55,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#   8%|▊         | 6/78 [00:04<00:54,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#   9%|▉         | 7/78 [00:05<00:54,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  10%|█         | 8/78 [00:06<00:53,  1.30it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  12%|█▏        | 9/78 [00:06<00:52,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  13%|█▎        | 10/78 [00:07<00:51,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  14%|█▍        | 11/78 [00:08<00:51,  1.30it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  15%|█▌        | 12/78 [00:09<00:50,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  17%|█▋        | 13/78 [00:09<00:49,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  18%|█▊        | 14/78 [00:10<00:48,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  19%|█▉        | 15/78 [00:11<00:48,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  21%|██        | 16/78 [00:12<00:47,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  22%|██▏       | 17/78 [00:13<00:46,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  23%|██▎       | 18/78 [00:13<00:45,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  24%|██▍       | 19/78 [00:14<00:44,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  26%|██▌       | 20/78 [00:15<00:44,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  27%|██▋       | 21/78 [00:16<00:43,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  28%|██▊       | 22/78 [00:16<00:42,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  29%|██▉       | 23/78 [00:17<00:41,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  31%|███       | 24/78 [00:18<00:40,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  32%|███▏      | 25/78 [00:19<00:40,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  33%|███▎      | 26/78 [00:19<00:39,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  35%|███▍      | 27/78 [00:20<00:38,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  36%|███▌      | 28/78 [00:21<00:37,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  37%|███▋      | 29/78 [00:22<00:37,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  38%|███▊      | 30/78 [00:22<00:36,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  40%|███▉      | 31/78 [00:23<00:35,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  41%|████      | 32/78 [00:24<00:34,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  42%|████▏     | 33/78 [00:25<00:33,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  44%|████▎     | 34/78 [00:25<00:33,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  45%|████▍     | 35/78 [00:26<00:32,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  46%|████▌     | 36/78 [00:27<00:32,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  47%|████▋     | 37/78 [00:28<00:31,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  49%|████▊     | 38/78 [00:28<00:30,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  50%|█████     | 39/78 [00:29<00:29,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  51%|█████▏    | 40/78 [00:30<00:28,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  53%|█████▎    | 41/78 [00:31<00:28,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  54%|█████▍    | 42/78 [00:31<00:27,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  55%|█████▌    | 43/78 [00:32<00:26,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  56%|█████▋    | 44/78 [00:33<00:25,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  58%|█████▊    | 45/78 [00:34<00:25,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  59%|█████▉    | 46/78 [00:34<00:24,  1.31it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  60%|██████    | 47/78 [00:35<00:23,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  62%|██████▏   | 48/78 [00:36<00:22,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  63%|██████▎   | 49/78 [00:37<00:21,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  64%|██████▍   | 50/78 [00:37<00:21,  1.32it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  65%|██████▌   | 51/78 [00:38<00:20,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  67%|██████▋   | 52/78 [00:39<00:19,  1.33it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# ...
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  86%|████████▌ | 12/14 [00:13<00:02,  1.10s/it]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  93%|█████████▎| 13/14 [00:14<00:01,  1.13s/it]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# 100%|██████████| 14/14 [00:16<00:00,  1.15s/it]
# loading annotations into memory...
# Done (t=0.10s)
# creating index...
# index created!
#   0%|          | 0/9 [00:00<?, ?it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  11%|█         | 1/9 [00:00<00:06,  1.24it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  22%|██▏       | 2/9 [00:01<00:05,  1.28it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  33%|███▎      | 3/9 [00:02<00:04,  1.29it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  44%|████▍     | 4/9 [00:03<00:05,  1.02s/it]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  56%|█████▌    | 5/9 [00:04<00:04,  1.03s/it]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  67%|██████▋   | 6/9 [00:05<00:03,  1.06s/it]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  78%|███████▊  | 7/9 [00:06<00:02,  1.06s/it]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  89%|████████▉ | 8/9 [00:08<00:01,  1.09s/it]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# 100%|██████████| 9/9 [00:09<00:00,  1.02s/it]
# loading annotations into memory...
# Done (t=0.10s)
# creating index...
# index created!
#   0%|          | 0/5 [00:00<?, ?it/s]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  20%|██        | 1/5 [00:01<00:07,  1.76s/it]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  40%|████      | 2/5 [00:03<00:04,  1.57s/it]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  60%|██████    | 3/5 [00:05<00:03,  1.68s/it]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#  80%|████████  | 4/5 [00:06<00:01,  1.55s/it]/opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/transformers/modeling_utils.py:962: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/tljh/user/envs/opschotdetectie2/lib/python3.11/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# 100%|██████████| 5/5 [00:07<00:00,  1.57s/it]

# %%
df_seg_shapes
# Out:
# {'category': [],
#  'tile_path': ['data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_0.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_10.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_11.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_12.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_13.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_14.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_15.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_16.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_17.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_18.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_19.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_1.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_20.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_21.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_22.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_23.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_24.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_25.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_26.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_27.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_28.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_29.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_2.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_30.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_31.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_32.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_33.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_34.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_35.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_36.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_37.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_38.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_39.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_3.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_40.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_41.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_42.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_43.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_44.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_45.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_46.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_47.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_48.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_49.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_4.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_50.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_51.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_52.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_53.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_54.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_55.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_56.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_57.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_58.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_59.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_5.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_60.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_61.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_62.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_63.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_64.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_65.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_66.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_67.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_68.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_69.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_6.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_70.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_71.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_72.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_73.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_74.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_75.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_76.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_77.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_7.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_8.jpeg',
#   'data/supervisely/2023-12-12 08:04:16.739/images/20230714 MUG Medemblik Den Oever orthomosaic deel 14_9.jpeg'],
#  'tile_fname': ['20230714 MUG Medemblik Den Oever orthomosaic deel 14_0',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_10',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_11',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_12',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_13',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_14',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_15',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_16',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_17',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_18',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_19',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_1',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_20',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_21',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_22',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_23',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_24',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_25',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_26',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_27',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_28',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_29',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_2',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_30',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_31',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_32',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_33',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_34',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_35',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_36',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_37',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_38',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_39',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_3',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_40',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_41',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_42',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_43',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_44',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_45',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_46',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_47',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_48',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_49',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_4',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_50',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_51',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_52',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_53',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_54',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_55',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_56',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_57',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_58',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_59',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_5',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_60',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_61',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_62',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_63',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_64',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_65',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_66',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_67',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_68',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_69',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_6',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_70',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_71',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_72',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_73',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_74',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_75',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_76',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_77',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_7',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_8',
#   '20230714 MUG Medemblik Den Oever orthomosaic deel 14_9'],
#  'project_name': ['20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14',
#   '20230714_MUG_Medemblik_Den_Oever_orthomosaic_deel_14'],
#  'geometry': []}
